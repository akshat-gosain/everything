# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import networkx as nx

# %%
a=int(input("Enter dataset numer: "))
if a==1:
    df = pd.read_csv("data_set - Sheet1.csv")
elif a==2:
    df = pd.read_csv("data_set - Sheet2.csv")
elif a==3:
    df = pd.read_csv("data_set - Sheet3.csv")
elif a==4:
    df = pd.read_csv("data_set - Sheet4.csv")
elif a==5:
    df = pd.read_csv("data_set - Sheet5.csv")
# Out:
# Enter dataset numer: 5

# %%
df.head()
# Out:
#       NAME  Rank CATEGORY     P1     P2    P3     P4    P5    P6    P7    P8  \
# 0    Aiden     0       X1   FDC7   FDE5  HDE2   HDC4  HDE4  FDC5  HDC1  FDC2
# 1    Bella     0       X1   FDE5  FDC11  HDC2   FDC2  FDC5  FDE3  HDE4  FDC8
# 2    Caleb     0       X1   FDC2   HDC2  FDE6   FDC9  FDC5  FDC8  HDE1  HDC4
# 3  Delilah     0       X1   FDE1   HDE3  FDC1   HDE1  FDC9  FDC8  FDE3  HDC2
# 4    Ethan     0       X1  FDC10   FDE6  FDE5  FDC11  HDE4  FDC5  HDC2  HDE2
#
#      P9   P10
# 0  FDC1  FDE6
# 1  HDC3  HDE3
# 2  HDE3  FDE4
# 3  FDC6  HDC4
# 4  FDC9  HDC1

# %%
df.loc[df['CATEGORY'] == 'X1', 'CATEGORY'] = 0.5
df.loc[df['CATEGORY'] == 'X2', 'CATEGORY'] = 1
df.loc[df['CATEGORY'] == 'X3', 'CATEGORY'] = 1.5

# %%
'''
for _ in range(30):
    random_number = np.random.randint(1, 31)
    df.loc[df['Rank']==0,'Rank'] = random_number
    for i in range(1,30):
        ndf=df.iloc[i:]
        if ndf['Rank'].isin([random_number]).any():
            a=random_number
            random_number = np.random.randint(1, 31)
            ndf.loc[df['Rank']==a,'Rank'] = random_number
            
ndf=df
df
''' 
random_ranks = np.random.permutation(np.arange(1, 31))
df['Rank'] = random_ranks
df.sort_values('Rank',inplace=True)

# %%
df
# Out:
#          NAME  Rank CATEGORY     P1     P2     P3     P4    P5     P6     P7  \
# 1       Bella     1      0.5   FDE5  FDC11   HDC2   FDC2  FDC5   FDE3   HDE4
# 7      Hannah     2      0.5   HDE1   FDE1   FDC5   FDE6  FDC2   FDC3   HDC1
# 16    Quentin     3        1   FDE6   HDC4   FDC3   FDC4  HDC1  FDC11   HDE3
# 22    William     4      1.5  FDC11   HDC1   HDE2   FDC7  HDE1   FDE1  FDC10
# 4       Ethan     5      0.5  FDC10   FDE6   FDE5  FDC11  HDE4   FDC5   HDC2
# 11       Lily     6        1   FDC8   FDE3   HDE2   FDC3  HDC4   FDC2   HDE4
# 15   Penelope     7        1   FDE1   HDC4   HDE3   FDC6  HDC1   FDC4   HDE2
# 0       Aiden     8      0.5   FDC7   FDE5   HDE2   HDC4  HDE4   FDC5   HDC1
# 23       Xena     9      1.5   FDC8   HDC4   HDC3   FDC7  FDE3   HDE1   HDE2
# 12      Mason    10        1   FDE2   FDE3   FDC1   HDE4  FDC5   FDC4   HDC4
# 26     Donald    11      1.5  FDC10   HDC3  FDC11   FDC5  FDC3   HDE4   FDE6
# 6     Gabriel    12      0.5  FDC11   FDC9   HDE2   HDC3  FDE6   HDC1   FDC6
# 10      Kaden    13        1   FDC8   FDE4  FDC11   HDC2  FDC9   HDE3   HDC4
# 9     Jasmine    14      0.5   FDE1  FDC11   HDC2   HDC1  HDE4   FDC1   FDE5
# 8       Isaac    15      0.5   HDE4   FDC2   HDC4   FDE5  FDC7   HDE2   HDC1
# 20      Uriel    16      1.5   FDE2   FDC1   FDC5   FDC3  HDC2   HDE3   FDE5
# 19      Tessa    17      1.5   FDC7   HDE4   FDC4   FDC2  HDE3   FDE6   HDC3
# 5       Fiona    18      0.5   FDC4   HDE2   FDC9   FDE6  FDE5   HDE1   FDC7
# 29      Abdul    19      1.5   HDE3   FDE6   HDC3  FDC10  HDC2  FDC11   FDC9
# 27       Zari    20      1.5   HDE2   FDC2   FDC3   FDE4  HDE3   HDC3   FDC5
# 13       Nora    21        1   FDC3   HDC1   FDE6   HDC2  HDE3   HDE2   FDC8
# 25     Daniel    22      1.5   FDC3   HDC1   FDC5   FDC2  FDE4   HDC4   FDC7
# 24      Yosef    23      1.5   FDE3   HDC2   FDC8   HDE4  HDC4  FDC11   HDE2
# 17       Rose    24        1   FDC8   HDC1   HDE3   FDC4  FDE1   HDE2   FDE5
# 21     Violet    25      1.5   HDC3  FDC11   HDE3   FDE3  FDC2   FDC5   HDC4
# 28      Mohar    26      1.5   HDC4  FDC10  FDC11   HDE2  FDE3   FDE2   HDC2
# 18  Sebastian    27      1.5   FDC8   FDE3   FDC7   HDE2  HDE1   FDC9   FDE6
# 3     Delilah    28      0.5   FDE1   HDE3   FDC1   HDE1  FDC9   FDC8   FDE3
# 2       Caleb    29      0.5   FDC2   HDC2   FDE6   FDC9  FDC5   FDC8   HDE1
# 14     Oliver    30        1   HDC1   FDC5   FDE6   HDE4  HDC4   FDE1   FDC6
#
#        P8     P9   P10
# 1    FDC8   HDC3  HDE3
# 7    HDE4   HDC2  FDC4
# 16   FDC7   HDE4  FDE4
# 22   FDC2   HDC3  FDE3
# 4    HDE2   FDC9  HDC1
# 11   FDE2   FDC4  HDC1
# 15   FDE2   FDC8  FDC7
# 0    FDC2   FDC1  FDE6
# 23   FDC9  FDC10  FDE6
# 12   HDE3   FDC6  HDC1
# 26   HDC1   HDE3  FDE4
# 6    FDE3  FDC10  HDE1
# 10   FDE6   HDE1  FDC4
# 9    FDC5   FDC2  HDE1
# 8    FDC9   FDC6  FDE6
# 20   HDC1   HDE2  FDC4
# 19   HDC4   FDC5  FDE1
# 5    HDC2  FDC11  HDC1
# 29   FDC7   FDE5  HDE1
# 27   FDE6   FDC7  HDC1
# 13  FDC10   FDE3  FDC1
# 25   FDE2   HDE2  HDE1
# 24  FDC10   FDE1  FDC9
# 17   FDC6   FDC9  HDC4
# 21   FDC6   FDE2  HDE1
# 28   FDC3   HDE1  FDC7
# 18   HDC3   HDC2  FDC1
# 3    HDC2   FDC6  HDC4
# 2    HDC4   HDE3  FDE4
# 14  FDC11   FDC7  HDE3

# %%
FDC ={'FDC1': 1, 'FDC2': 1, 'FDC3': 1, 'FDC4': 1, 'FDC5': 1, 'FDC6': 1, 'FDC7': 1, 'FDC8': 1, 'FDC9': 1, 'FDC10': 1, 'FDC11': 1}
HDC={'HDC1': 1, 'HDC2': 1, 'HDC3': 1, 'HDC4': 1}
FDE = {'FDE1': 1, 'FDE2': 1, 'FDE3': 1, 'FDE4': 1, 'FDE5': 1, 'FDE6': 1}
HDE = {'HDE1': 1, 'HDE2': 1, 'HDE3': 1, 'HDE4': 1}
test = {**FDC, **HDC}
only_once=[]
for key in test:
    occurrences = df.values.flatten().tolist().count(key)
    if(occurrences==1):
        only_once.append(key)

# %%
proff_dict={}
for i in range(df.shape[0]):
    proff_list=df.iloc[i].tolist()
    proff_dict[proff_list[0]]=proff_list[1:]
print(proff_dict)
# Out:
# {'Bella': [1, 0.5, 'FDE5', 'FDC11', 'HDC2', 'FDC2', 'FDC5', 'FDE3', 'HDE4', 'FDC8', 'HDC3', 'HDE3'], 'Hannah': [2, 0.5, 'HDE1', 'FDE1', 'FDC5', 'FDE6', 'FDC2', 'FDC3', 'HDC1', 'HDE4', 'HDC2', 'FDC4'], 'Quentin': [3, 1, 'FDE6', 'HDC4', 'FDC3', 'FDC4', 'HDC1', 'FDC11', 'HDE3', 'FDC7', 'HDE4', 'FDE4'], 'William': [4, 1.5, 'FDC11', 'HDC1', 'HDE2', 'FDC7', 'HDE1', 'FDE1', 'FDC10', 'FDC2', 'HDC3', 'FDE3'], 'Ethan': [5, 0.5, 'FDC10', 'FDE6', 'FDE5', 'FDC11', 'HDE4', 'FDC5', 'HDC2', 'HDE2', 'FDC9', 'HDC1'], 'Lily': [6, 1, 'FDC8', 'FDE3', 'HDE2', 'FDC3', 'HDC4', 'FDC2', 'HDE4', 'FDE2', 'FDC4', 'HDC1'], 'Penelope': [7, 1, 'FDE1', 'HDC4', 'HDE3', 'FDC6', 'HDC1', 'FDC4', 'HDE2', 'FDE2', 'FDC8', 'FDC7'], 'Aiden': [8, 0.5, 'FDC7', 'FDE5', 'HDE2', 'HDC4', 'HDE4', 'FDC5', 'HDC1', 'FDC2', 'FDC1', 'FDE6'], 'Xena': [9, 1.5, 'FDC8', 'HDC4', 'HDC3', 'FDC7', 'FDE3', 'HDE1', 'HDE2', 'FDC9', 'FDC10', 'FDE6'], 'Mason': [10, 1, 'FDE2', 'FDE3', 'FDC1', 'HDE4', 'FDC5', 'FDC4', 'HDC4', 'HDE3', 'FDC6', 'HDC1'], 'Donald': [11, 1.5, 'FDC10', 'HDC3', 'FDC11', 'FDC5', 'FDC3', 'HDE4', 'FDE6', 'HDC1', 'HDE3', 'FDE4'], 'Gabriel': [12, 0.5, 'FDC11', 'FDC9', 'HDE2', 'HDC3', 'FDE6', 'HDC1', 'FDC6', 'FDE3', 'FDC10', 'HDE1'], 'Kaden': [13, 1, 'FDC8', 'FDE4', 'FDC11', 'HDC2', 'FDC9', 'HDE3', 'HDC4', 'FDE6', 'HDE1', 'FDC4'], 'Jasmine': [14, 0.5, 'FDE1', 'FDC11', 'HDC2', 'HDC1', 'HDE4', 'FDC1', 'FDE5', 'FDC5', 'FDC2', 'HDE1'], 'Isaac': [15, 0.5, 'HDE4', 'FDC2', 'HDC4', 'FDE5', 'FDC7', 'HDE2', 'HDC1', 'FDC9', 'FDC6', 'FDE6'], 'Uriel': [16, 1.5, 'FDE2', 'FDC1', 'FDC5', 'FDC3', 'HDC2', 'HDE3', 'FDE5', 'HDC1', 'HDE2', 'FDC4'], 'Tessa': [17, 1.5, 'FDC7', 'HDE4', 'FDC4', 'FDC2', 'HDE3', 'FDE6', 'HDC3', 'HDC4', 'FDC5', 'FDE1'], 'Fiona': [18, 0.5, 'FDC4', 'HDE2', 'FDC9', 'FDE6', 'FDE5', 'HDE1', 'FDC7', 'HDC2', 'FDC11', 'HDC1'], 'Abdul': [19, 1.5, 'HDE3', 'FDE6', 'HDC3', 'FDC10', 'HDC2', 'FDC11', 'FDC9', 'FDC7', 'FDE5', 'HDE1'], 'Zari': [20, 1.5, 'HDE2', 'FDC2', 'FDC3', 'FDE4', 'HDE3', 'HDC3', 'FDC5', 'FDE6', 'FDC7', 'HDC1'], 'Nora': [21, 1, 'FDC3', 'HDC1', 'FDE6', 'HDC2', 'HDE3', 'HDE2', 'FDC8', 'FDC10', 'FDE3', 'FDC1'], 'Daniel': [22, 1.5, 'FDC3', 'HDC1', 'FDC5', 'FDC2', 'FDE4', 'HDC4', 'FDC7', 'FDE2', 'HDE2', 'HDE1'], 'Yosef': [23, 1.5, 'FDE3', 'HDC2', 'FDC8', 'HDE4', 'HDC4', 'FDC11', 'HDE2', 'FDC10', 'FDE1', 'FDC9'], 'Rose': [24, 1, 'FDC8', 'HDC1', 'HDE3', 'FDC4', 'FDE1', 'HDE2', 'FDE5', 'FDC6', 'FDC9', 'HDC4'], 'Violet': [25, 1.5, 'HDC3', 'FDC11', 'HDE3', 'FDE3', 'FDC2', 'FDC5', 'HDC4', 'FDC6', 'FDE2', 'HDE1'], 'Mohar': [26, 1.5, 'HDC4', 'FDC10', 'FDC11', 'HDE2', 'FDE3', 'FDE2', 'HDC2', 'FDC3', 'HDE1', 'FDC7'], 'Sebastian': [27, 1.5, 'FDC8', 'FDE3', 'FDC7', 'HDE2', 'HDE1', 'FDC9', 'FDE6', 'HDC3', 'HDC2', 'FDC1'], 'Delilah': [28, 0.5, 'FDE1', 'HDE3', 'FDC1', 'HDE1', 'FDC9', 'FDC8', 'FDE3', 'HDC2', 'FDC6', 'HDC4'], 'Caleb': [29, 0.5, 'FDC2', 'HDC2', 'FDE6', 'FDC9', 'FDC5', 'FDC8', 'HDE1', 'HDC4', 'HDE3', 'FDE4'], 'Oliver': [30, 1, 'HDC1', 'FDC5', 'FDE6', 'HDE4', 'HDC4', 'FDE1', 'FDC6', 'FDC11', 'FDC7', 'HDE3']}

# %%
FDC ={'FDC1': 1, 'FDC2': 1, 'FDC3': 1, 'FDC4': 1, 'FDC5': 1, 'FDC6': 1, 'FDC7': 1, 'FDC8': 1, 'FDC9': 1, 'FDC10': 1, 'FDC11': 1}
HDC={'HDC1': 1, 'HDC2': 1, 'HDC3': 1, 'HDC4': 1}
FDE = {'FDE1': 1, 'FDE2': 1, 'FDE3': 1, 'FDE4': 1, 'FDE5': 1, 'FDE6': 1}
HDE = {'HDE1': 1, 'HDE2': 1, 'HDE3': 1, 'HDE4': 1}
#courses_offered=['FDC','HDC','FDE','HDE']

# %%
allot_dict = {key: [] for key in set(FDC) | set(HDC) | set(FDE) | set(HDE)}

print(allot_dict)
# Out:
# {'HDC2': [], 'FDC8': [], 'HDC4': [], 'HDE2': [], 'FDC11': [], 'FDE4': [], 'HDE4': [], 'FDC2': [], 'FDC7': [], 'FDC6': [], 'FDE5': [], 'FDC5': [], 'HDC1': [], 'HDE3': [], 'FDC3': [], 'FDC1': [], 'FDE3': [], 'HDE1': [], 'FDE6': [], 'FDE1': [], 'FDC4': [], 'FDC10': [], 'FDE2': [], 'HDC3': [], 'FDC9': []}

# %%
def assign_course(prof_name,course_name):
    for i in allot_dict:
        if i==course_name:
            allot_dict[i].append(prof_name)

# %%
def check_total(x):
    total=0
    for i in x:
        total+=x[i]
    if total==0:
        return True
    else:
        return False

# %%
def preference_priority(x):
    if x==FDC:
        y='FDC'
    elif x==HDC:
        y='HDC'
    elif x==FDE:
        y='FDE'
    elif x==HDE:
        y='HDE'
    for i in range(2,12):
        for name in proff_dict:
            if proff_dict[name][i].startswith(y):
                course_name=proff_dict[name][i]
                if course_name in x:
                    if x[course_name] in [0.5,1] and proff_dict[name][1] in [0.5,1.5]:
                        if proff_dict[name][1] in [0.5,1.5] and course_name not in only_once:
                            assign_course(name,course_name)
                            x[course_name]-=0.5
                            proff_dict[name][1]-=0.5
                        elif proff_dict[name][1]==1.5 and course_name in only_once:
                            assign_course(name,course_name)
                            x[course_name]-=1
                            proff_dict[name][1]-=1
                    elif x[course_name]==1 and proff_dict[name][1] in [1,1.5]:
                        assign_course(name,course_name)
                        x[course_name]=0
                        proff_dict[name][1]-=1
        if check_total(x):
            break

# %%
# for i in range(1):
#     preference_priority(FDC)
#     if check_total(FDC)==True:
#         preference_priority(HDC)
#         if check_total(HDC)==True:
#             preference_priority(FDE)
#             if check_total(FDE)==True:
#                 preference_priority(HDE)
#         else:
#             continue
#     else:
#         continue 
preference_priority(FDC)
preference_priority(HDC)
preference_priority(FDE)
preference_priority(HDE)

# %%
FDC
# Out:
# {'FDC1': 0.0,
#  'FDC2': 0.0,
#  'FDC3': 0,
#  'FDC4': 0.0,
#  'FDC5': 0,
#  'FDC6': 0,
#  'FDC7': 0.0,
#  'FDC8': 0,
#  'FDC9': 0,
#  'FDC10': 0.0,
#  'FDC11': 0.0}

# %%
HDC
# Out:
# {'HDC1': 0, 'HDC2': 0.0, 'HDC3': 0.0, 'HDC4': 0.0}

# %%
FDE
# Out:
# {'FDE1': 0.5, 'FDE2': 0, 'FDE3': 0, 'FDE4': 0.0, 'FDE5': 0, 'FDE6': 0}

# %%
HDE
# Out:
# {'HDE1': 0.5, 'HDE2': 0, 'HDE3': 0, 'HDE4': 0}

# %%
allot_dict
# Out:
# {'HDC2': ['Yosef', 'Bella'],
#  'FDC8': ['Lily'],
#  'HDC4': ['Mohar', 'Xena'],
#  'HDE2': ['Zari'],
#  'FDC11': ['William', 'Gabriel'],
#  'FDE4': ['Zari', 'Daniel'],
#  'HDE4': ['Tessa'],
#  'FDC2': ['Caleb', 'Isaac'],
#  'FDC7': ['Aiden', 'Tessa'],
#  'FDC6': ['Penelope'],
#  'FDE5': ['Uriel'],
#  'FDC5': ['Oliver'],
#  'HDC1': ['William'],
#  'HDE3': ['Abdul'],
#  'FDC3': ['Nora'],
#  'FDC1': ['Uriel', 'Delilah'],
#  'FDE3': ['Yosef'],
#  'HDE1': ['Sebastian'],
#  'FDE6': ['Quentin'],
#  'FDE1': ['Jasmine'],
#  'FDC4': ['Fiona', 'Hannah'],
#  'FDC10': ['Ethan', 'Donald'],
#  'FDE2': ['Mason'],
#  'HDC3': ['Violet', 'Abdul'],
#  'FDC9': ['Kaden']}

# %%
for key in FDE:
    if FDE[key]==0.5:
        FDE[key]+=0.5
        proff=allot_dict[key][0]
        allot_dict[key]=[]
        proff_dict[proff][1]+=0.5
for key in HDE:
    if HDE[key]==0.5:
        HDE[key]+=0.5
        proff=allot_dict[key][0]
        allot_dict[key]=[]
        proff_dict[proff][1]+=0.5
allot_dict
# Out:
# {'HDC2': ['Yosef', 'Bella'],
#  'FDC8': ['Lily'],
#  'HDC4': ['Mohar', 'Xena'],
#  'HDE2': ['Zari'],
#  'FDC11': ['William', 'Gabriel'],
#  'FDE4': ['Zari', 'Daniel'],
#  'HDE4': ['Tessa'],
#  'FDC2': ['Caleb', 'Isaac'],
#  'FDC7': ['Aiden', 'Tessa'],
#  'FDC6': ['Penelope'],
#  'FDE5': ['Uriel'],
#  'FDC5': ['Oliver'],
#  'HDC1': ['William'],
#  'HDE3': ['Abdul'],
#  'FDC3': ['Nora'],
#  'FDC1': ['Uriel', 'Delilah'],
#  'FDE3': ['Yosef'],
#  'HDE1': [],
#  'FDE6': ['Quentin'],
#  'FDE1': [],
#  'FDC4': ['Fiona', 'Hannah'],
#  'FDC10': ['Ethan', 'Donald'],
#  'FDE2': ['Mason'],
#  'HDC3': ['Violet', 'Abdul'],
#  'FDC9': ['Kaden']}

# %%
print(HDE)
FDE
# Out:
# {'HDE1': 1.0, 'HDE2': 0, 'HDE3': 0, 'HDE4': 0}
# {'FDE1': 1.0, 'FDE2': 0, 'FDE3': 0, 'FDE4': 0.0, 'FDE5': 0, 'FDE6': 0}

# %%
r_proff=[]
for prof in proff_dict:
    if(proff_dict[prof][1]!=0):
        r_proff.append(prof)

# %%
df = pd.DataFrame(allot_dict.items(), columns=['Courses', 'Professors'])
df[['Professor1', 'Professor2']] = pd.DataFrame(df['Professors'].tolist(),index=df.index)
df = df.drop(columns='Professors')
def custom_sort(course):
    letters = course[:3]
    number = int(course[3:])
    category_order = {'FDC': 1, 'HDC': 2, 'FDE': 3, 'HDE': 4}
    return (category_order[letters], number)

df['sort_key'] = df['Courses'].apply(custom_sort)
df = df.sort_values('sort_key').drop(columns='sort_key')
df = df.reset_index(drop=True)

# %%
def red(x):
    if pd.isna(x):
        return 'font-weight: bold; color: red'
    else:
        return ''

styled_df = df.style.applymap(red)
styled_df.to_excel('styled_dataset.xlsx', index=False)
styled_df
# Out:
# <style type="text/css">
# #T_f98dc_row2_col2, #T_f98dc_row4_col2, #T_f98dc_row5_col2, #T_f98dc_row7_col2, #T_f98dc_row8_col2, #T_f98dc_row11_col2, #T_f98dc_row15_col1, #T_f98dc_row15_col2, #T_f98dc_row16_col2, #T_f98dc_row17_col2, #T_f98dc_row19_col2, #T_f98dc_row20_col2, #T_f98dc_row21_col1, #T_f98dc_row21_col2, #T_f98dc_row22_col2, #T_f98dc_row23_col2, #T_f98dc_row24_col2 {
#   font-weight: bold;
#   color: red;
# }
# </style>
# <table id="T_f98dc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f98dc_level0_col0" class="col_heading level0 col0" >Courses</th>
#       <th id="T_f98dc_level0_col1" class="col_heading level0 col1" >Professor1</th>
#       <th id="T_f98dc_level0_col2" class="col_heading level0 col2" >Professor2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f98dc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f98dc_row0_col0" class="data row0 col0" >FDC1</td>
#       <td id="T_f98dc_row0_col1" class="data row0 col1" >Uriel</td>
#       <td id="T_f98dc_row0_col2" class="data row0 col2" >Delilah</td>
#     </tr>
#     <tr>
#       <th id="T_f98dc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f98dc_row1_col0" class="data row1 col0" >FDC2</td>
#       <td id="T_f98dc_row1_col1" class="data row1 col1" >Caleb</td>
#       <td id="T_f98dc_row1_col2" class="data row1 col2" >Isaac</td>
#     </tr>
#     <tr>
#       <th id="T_f98dc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f98dc_row2_col0" class="data row2 col0" >FDC3</td>
#       <td id="T_f98dc_row2_col1" class="data row2 col1" >Nora</td>
#       <td id="T_f98dc_row2_col2" class="data row2 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f98dc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f98dc_row3_col0" class="data row3 col0" >FDC4</td>
#       <td id="T_f98dc_row3_col1" class="data row3 col1" >Fiona</td>
#       <td id="T_f98dc_row3_col2" class="data row3 col2" >Hannah</td>
#     </tr>
#     <tr>
#       <th id="T_f98dc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f98dc_row4_col0" class="data row4 col0" >FDC5</td>
#       <td id="T_f98dc_row4_col1" class="data row4 col1" >Oliver</td>
#       <td id="T_f98dc_row4_col2" class="data row4 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f98dc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f98dc_row5_col0" class="data row5 col0" >FDC6</td>
#       <td id="T_f98dc_row5_col1" class="data row5 col1" >Penelope</td>
#       <td id="T_f98dc_row5_col2" class="data row5 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f98dc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f98dc_row6_col0" class="data row6 col0" >FDC7</td>
#       <td id="T_f98dc_row6_col1" class="data row6 col1" >Aiden</td>
#       <td id="T_f98dc_row6_col2" class="data row6 col2" >Tessa</td>
#     </tr>
#     <tr>
#       <th id="T_f98dc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f98dc_row7_col0" class="data row7 col0" >FDC8</td>
#       <td id="T_f98dc_row7_col1" class="data row7 col1" >Lily</td>
#       <td id="T_f98dc_row7_col2" class="data row7 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f98dc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f98dc_row8_col0" class="data row8 col0" >FDC9</td>
#       <td id="T_f98dc_row8_col1" class="data row8 col1" >Kaden</td>
#       <td id="T_f98dc_row8_col2" class="data row8 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f98dc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f98dc_row9_col0" class="data row9 col0" >FDC10</td>
#       <td id="T_f98dc_row9_col1" class="data row9 col1" >Ethan</td>
#       <td id="T_f98dc_row9_col2" class="data row9 col2" >Donald</td>
#     </tr>
#     <tr>
#       <th id="T_f98dc_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f98dc_row10_col0" class="data row10 col0" >FDC11</td>
#       <td id="T_f98dc_row10_col1" class="data row10 col1" >William</td>
#       <td id="T_f98dc_row10_col2" class="data row10 col2" >Gabriel</td>
#     </tr>
#     <tr>
#       <th id="T_f98dc_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f98dc_row11_col0" class="data row11 col0" >HDC1</td>
#       <td id="T_f98dc_row11_col1" class="data row11 col1" >William</td>
#       <td id="T_f98dc_row11_col2" class="data row11 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f98dc_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f98dc_row12_col0" class="data row12 col0" >HDC2</td>
#       <td id="T_f98dc_row12_col1" class="data row12 col1" >Yosef</td>
#       <td id="T_f98dc_row12_col2" class="data row12 col2" >Bella</td>
#     </tr>
#     <tr>
#       <th id="T_f98dc_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f98dc_row13_col0" class="data row13 col0" >HDC3</td>
#       <td id="T_f98dc_row13_col1" class="data row13 col1" >Violet</td>
#       <td id="T_f98dc_row13_col2" class="data row13 col2" >Abdul</td>
#     </tr>
#     <tr>
#       <th id="T_f98dc_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f98dc_row14_col0" class="data row14 col0" >HDC4</td>
#       <td id="T_f98dc_row14_col1" class="data row14 col1" >Mohar</td>
#       <td id="T_f98dc_row14_col2" class="data row14 col2" >Xena</td>
#     </tr>
#     <tr>
#       <th id="T_f98dc_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f98dc_row15_col0" class="data row15 col0" >FDE1</td>
#       <td id="T_f98dc_row15_col1" class="data row15 col1" >None</td>
#       <td id="T_f98dc_row15_col2" class="data row15 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f98dc_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f98dc_row16_col0" class="data row16 col0" >FDE2</td>
#       <td id="T_f98dc_row16_col1" class="data row16 col1" >Mason</td>
#       <td id="T_f98dc_row16_col2" class="data row16 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f98dc_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f98dc_row17_col0" class="data row17 col0" >FDE3</td>
#       <td id="T_f98dc_row17_col1" class="data row17 col1" >Yosef</td>
#       <td id="T_f98dc_row17_col2" class="data row17 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f98dc_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f98dc_row18_col0" class="data row18 col0" >FDE4</td>
#       <td id="T_f98dc_row18_col1" class="data row18 col1" >Zari</td>
#       <td id="T_f98dc_row18_col2" class="data row18 col2" >Daniel</td>
#     </tr>
#     <tr>
#       <th id="T_f98dc_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f98dc_row19_col0" class="data row19 col0" >FDE5</td>
#       <td id="T_f98dc_row19_col1" class="data row19 col1" >Uriel</td>
#       <td id="T_f98dc_row19_col2" class="data row19 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f98dc_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f98dc_row20_col0" class="data row20 col0" >FDE6</td>
#       <td id="T_f98dc_row20_col1" class="data row20 col1" >Quentin</td>
#       <td id="T_f98dc_row20_col2" class="data row20 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f98dc_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_f98dc_row21_col0" class="data row21 col0" >HDE1</td>
#       <td id="T_f98dc_row21_col1" class="data row21 col1" >None</td>
#       <td id="T_f98dc_row21_col2" class="data row21 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f98dc_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_f98dc_row22_col0" class="data row22 col0" >HDE2</td>
#       <td id="T_f98dc_row22_col1" class="data row22 col1" >Zari</td>
#       <td id="T_f98dc_row22_col2" class="data row22 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f98dc_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_f98dc_row23_col0" class="data row23 col0" >HDE3</td>
#       <td id="T_f98dc_row23_col1" class="data row23 col1" >Abdul</td>
#       <td id="T_f98dc_row23_col2" class

# %%
professor_counts = df[['Professor1', 'Professor2']].count(axis=1)

plt.figure(figsize=(10, 6))
plt.bar(df['Courses'], professor_counts, color='skyblue')
plt.xlabel('Courses')
plt.ylabel('Number of Professors')
plt.title('Number of Professors per Course')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
