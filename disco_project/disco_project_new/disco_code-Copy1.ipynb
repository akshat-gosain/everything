# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import networkx as nx
from mpl_toolkits.mplot3d import Axes3D

# %%
a=int(input("Enter dataset numer: "))
df = pd.read_csv(f"data_set - Sheet{a}.csv")
# Out:
# Enter dataset numer: 6

# %%
df.head()
# Out:
#       NAME  Rank CATEGORY    P1     P2    P3     P4    P5     P6    P7    P8  \
# 0    Aiden     0       X1  FDC9   FDC4  HDC3   FDC1  HDE3   HDC1  FDE2  FDE3
# 1    Bella     0       X1  FDE3   HDE3  HDE2   FDE1  FDC4   HDC4  FDC7  HDC2
# 2    Caleb     0       X1  HDC1   HDE1  HDC3   FDC5  HDE4  FDC10  FDC2  FDC6
# 3  Delilah     0       X1  FDC3   FDC2  FDC5   HDC4  HDE1   FDE6  HDC2  FDE1
# 4    Ethan     0       X3  HDE4  FDC11  FDE3  FDC10  HDC1   FDC7  FDC2  FDE5
#
#      P9   P10
# 0  HDE4  FDC3
# 1  FDC1  FDC2
# 2  FDE6  FDE4
# 3  HDE3  FDC9
# 4  HDE3  HDC2

# %%
df.loc[df['CATEGORY'] == 'X1', 'CATEGORY'] = 0.5
df.loc[df['CATEGORY'] == 'X2', 'CATEGORY'] = 1
df.loc[df['CATEGORY'] == 'X3', 'CATEGORY'] = 1.5

# %%
random_ranks = np.random.permutation(np.arange(1, df.shape[0]+1))
df['Rank'] = random_ranks
df.sort_values('Rank',inplace=True)

# %%
df
# Out:
#          NAME  Rank CATEGORY     P1     P2    P3     P4     P5     P6     P7  \
# 11       Lily     1        1   HDE3   FDC6  FDC2   FDC5   FDC4   HDC2   FDE3
# 6     Gabriel     2      0.5   FDC6   HDC4  FDE3  FDC10   HDC3   FDE5   HDE3
# 17       Rose     3        1   FDC9   HDE2  FDC3   FDE4   HDC4   HDE4   FDC4
# 0       Aiden     4      0.5   FDC9   FDC4  HDC3   FDC1   HDE3   HDC1   FDE2
# 19      Tessa     5      1.5   HDE1   FDC7  HDC4   HDE2   FDE4   FDC9  FDC10
# 3     Delilah     6      0.5   FDC3   FDC2  FDC5   HDC4   HDE1   FDE6   HDC2
# 12      Mason     7        1   HDC2   FDC9  HDC1   HDE3   FDC7   FDC1   HDE4
# 29      Abdul     8      1.5   FDE6   FDE3  FDC1   FDC5   FDC4   HDC2   HDE4
# 2       Caleb     9      0.5   HDC1   HDE1  HDC3   FDC5   HDE4  FDC10   FDC2
# 27       Zari    10      1.5  FDC10   HDE3  HDC1   HDC3   HDE2   FDC2   FDC4
# 26     Donald    11      1.5   FDE3   HDE1  FDE1   HDC1   HDE4   FDC1   FDC5
# 22    William    12      1.5   HDE2  FDC10  FDC2   HDC3   FDE6   FDE4   HDE1
# 13       Nora    13        1   HDC4   HDC3  HDE4   FDC6  FDC10   FDC8   FDE3
# 14     Oliver    14        1   FDC5   HDE1  HDE3   FDC6   FDE6   FDC4   HDC2
# 23       Xena    15      1.5   FDC5   FDE2  FDE6   HDC1   HDC2  FDC10   HDE2
# 5       Fiona    16      0.5   FDE6   FDC7  HDE1   HDE4   FDC6   FDE2   HDC3
# 8       Isaac    17      0.5   HDE3   HDE4  FDC3   FDE6   FDC2   HDC1   HDC2
# 9     Jasmine    18      0.5  FDC10   HDC4  FDC6   FDE1   HDC2   HDE3   FDC8
# 1       Bella    19      0.5   FDE3   HDE3  HDE2   FDE1   FDC4   HDC4   FDC7
# 10      Kaden    20        1   FDC4   HDE3  FDC6   HDC1   FDE6   FDE3   HDC4
# 24      Yosef    21      1.5   HDE3   HDC1  FDE3  FDC10   FDC2   FDC5   FDE6
# 4       Ethan    22      1.5   HDE4  FDC11  FDE3  FDC10   HDC1   FDC7   FDC2
# 7      Hannah    23      0.5  FDC10   HDE4  HDC3   FDC5   FDE5   HDE3   FDE4
# 18  Sebastian    24      1.5   FDC1   FDC5  HDC2   HDC4   FDE6   FDE4   HDE2
# 16    Quentin    25        1   FDC1  FDC10  HDC2   FDE6   FDE1   HDC1   HDE1
# 28      Mohar    26      1.5   FDE3   FDC1  FDE1   HDE4   HDC2   HDE3   FDC5
# 21     Violet    27      1.5   FDC1   FDE3  HDC1   FDE6   FDC2   FDC8   HDE4
# 25     Daniel    28      1.5   FDC6   FDC5  FDC3   HDE2   FDC7   FDE2   HDE3
# 15   Penelope    29        1   FDC1   HDE4  HDE1   HDC2   FDE1   HDC4   FDC5
# 20      Uriel    30      1.5   FDC9   HDC3  FDE4   HDC4   FDC7   FDC3   FDC8
#
#        P8    P9   P10
# 11   HDE4  FDE6  HDC3
# 6    FDC5  FDC8  HDE2
# 17   FDE2  HDC3  FDC5
# 0    FDE3  HDE4  FDC3
# 19   HDC2  FDE1  FDC8
# 3    FDE1  HDE3  FDC9
# 12   FDE4  FDE5  FDC2
# 29   FDC6  HDE3  HDC3
# 2    FDC6  FDE6  FDE4
# 27   FDC8  FDE4  FDE5
# 26  FDC10  FDC4  HDC3
# 22   HDC4  FDC4  FDC5
# 13   HDE3  FDC7  FDE2
# 14   FDE4  HDC3  FDC9
# 23   HDE4  FDC7  FDC2
# 5    FDC9  HDC1  FDC3
# 8    FDC4  FDC6  FDE1
# 9    HDE1  FDE6  FDC2
# 1    HDC2  FDC1  FDC2
# 10   HDE2  FDC1  FDC2
# 24   HDE2  HDC3  FDC1
# 4    FDE5  HDE3  HDC2
# 7    FDC4  HDC4  FDC7
# 18   FDC3  FDC2  HDE4
# 16   FDC4  HDE4  FDC9
# 28   FDC4  HDC1  FDC2
# 21  FDC10  HDE3  HDC4
# 25   HDC4  FDE3  HDC1
# 15  FDC10  FDE3  FDC6
# 20   HDE4  HDE2  FDE5

# %%
FDC ={'FDC1': 1, 'FDC2': 1, 'FDC3': 1, 'FDC4': 1, 'FDC5': 1, 'FDC6': 1, 'FDC7': 1, 'FDC8': 1, 'FDC9': 1, 'FDC10': 1, 'FDC11': 1}
HDC={'HDC1': 1, 'HDC2': 1, 'HDC3': 1, 'HDC4': 1}
FDE = {'FDE1': 1, 'FDE2': 1, 'FDE3': 1, 'FDE4': 1, 'FDE5': 1, 'FDE6': 1}
HDE = {'HDE1': 1, 'HDE2': 1, 'HDE3': 1, 'HDE4': 1}
test = {**FDC, **HDC}
only_once=[]
for key in test:
    occurrences = df.values.flatten().tolist().count(key)
    if(occurrences==1):
        only_once.append(key)
print(only_once)
# print(only_once)
# for once in only_once:
#     result = df[df.apply(lambda row: once in row.values, axis=1)]
#     print(result)
# Out:
# ['FDC11']

# %%
proff_dict={}
for i in range(df.shape[0]):
    proff_list=df.iloc[i].tolist()
    proff_dict[proff_list[0]]=proff_list[1:]
print(proff_dict)
# Out:
# {'Lily': [1, 1, 'HDE3', 'FDC6', 'FDC2', 'FDC5', 'FDC4', 'HDC2', 'FDE3', 'HDE4', 'FDE6', 'HDC3'], 'Gabriel': [2, 0.5, 'FDC6', 'HDC4', 'FDE3', 'FDC10', 'HDC3', 'FDE5', 'HDE3', 'FDC5', 'FDC8', 'HDE2'], 'Rose': [3, 1, 'FDC9', 'HDE2', 'FDC3', 'FDE4', 'HDC4', 'HDE4', 'FDC4', 'FDE2', 'HDC3', 'FDC5'], 'Aiden': [4, 0.5, 'FDC9', 'FDC4', 'HDC3', 'FDC1', 'HDE3', 'HDC1', 'FDE2', 'FDE3', 'HDE4', 'FDC3'], 'Tessa': [5, 1.5, 'HDE1', 'FDC7', 'HDC4', 'HDE2', 'FDE4', 'FDC9', 'FDC10', 'HDC2', 'FDE1', 'FDC8'], 'Delilah': [6, 0.5, 'FDC3', 'FDC2', 'FDC5', 'HDC4', 'HDE1', 'FDE6', 'HDC2', 'FDE1', 'HDE3', 'FDC9'], 'Mason': [7, 1, 'HDC2', 'FDC9', 'HDC1', 'HDE3', 'FDC7', 'FDC1', 'HDE4', 'FDE4', 'FDE5', 'FDC2'], 'Abdul': [8, 1.5, 'FDE6', 'FDE3', 'FDC1', 'FDC5', 'FDC4', 'HDC2', 'HDE4', 'FDC6', 'HDE3', 'HDC3'], 'Caleb': [9, 0.5, 'HDC1', 'HDE1', 'HDC3', 'FDC5', 'HDE4', 'FDC10', 'FDC2', 'FDC6', 'FDE6', 'FDE4'], 'Zari': [10, 1.5, 'FDC10', 'HDE3', 'HDC1', 'HDC3', 'HDE2', 'FDC2', 'FDC4', 'FDC8', 'FDE4', 'FDE5'], 'Donald': [11, 1.5, 'FDE3', 'HDE1', 'FDE1', 'HDC1', 'HDE4', 'FDC1', 'FDC5', 'FDC10', 'FDC4', 'HDC3'], 'William': [12, 1.5, 'HDE2', 'FDC10', 'FDC2', 'HDC3', 'FDE6', 'FDE4', 'HDE1', 'HDC4', 'FDC4', 'FDC5'], 'Nora': [13, 1, 'HDC4', 'HDC3', 'HDE4', 'FDC6', 'FDC10', 'FDC8', 'FDE3', 'HDE3', 'FDC7', 'FDE2'], 'Oliver': [14, 1, 'FDC5', 'HDE1', 'HDE3', 'FDC6', 'FDE6', 'FDC4', 'HDC2', 'FDE4', 'HDC3', 'FDC9'], 'Xena': [15, 1.5, 'FDC5', 'FDE2', 'FDE6', 'HDC1', 'HDC2', 'FDC10', 'HDE2', 'HDE4', 'FDC7', 'FDC2'], 'Fiona': [16, 0.5, 'FDE6', 'FDC7', 'HDE1', 'HDE4', 'FDC6', 'FDE2', 'HDC3', 'FDC9', 'HDC1', 'FDC3'], 'Isaac': [17, 0.5, 'HDE3', 'HDE4', 'FDC3', 'FDE6', 'FDC2', 'HDC1', 'HDC2', 'FDC4', 'FDC6', 'FDE1'], 'Jasmine': [18, 0.5, 'FDC10', 'HDC4', 'FDC6', 'FDE1', 'HDC2', 'HDE3', 'FDC8', 'HDE1', 'FDE6', 'FDC2'], 'Bella': [19, 0.5, 'FDE3', 'HDE3', 'HDE2', 'FDE1', 'FDC4', 'HDC4', 'FDC7', 'HDC2', 'FDC1', 'FDC2'], 'Kaden': [20, 1, 'FDC4', 'HDE3', 'FDC6', 'HDC1', 'FDE6', 'FDE3', 'HDC4', 'HDE2', 'FDC1', 'FDC2'], 'Yosef': [21, 1.5, 'HDE3', 'HDC1', 'FDE3', 'FDC10', 'FDC2', 'FDC5', 'FDE6', 'HDE2', 'HDC3', 'FDC1'], 'Ethan': [22, 1.5, 'HDE4', 'FDC11', 'FDE3', 'FDC10', 'HDC1', 'FDC7', 'FDC2', 'FDE5', 'HDE3', 'HDC2'], 'Hannah': [23, 0.5, 'FDC10', 'HDE4', 'HDC3', 'FDC5', 'FDE5', 'HDE3', 'FDE4', 'FDC4', 'HDC4', 'FDC7'], 'Sebastian': [24, 1.5, 'FDC1', 'FDC5', 'HDC2', 'HDC4', 'FDE6', 'FDE4', 'HDE2', 'FDC3', 'FDC2', 'HDE4'], 'Quentin': [25, 1, 'FDC1', 'FDC10', 'HDC2', 'FDE6', 'FDE1', 'HDC1', 'HDE1', 'FDC4', 'HDE4', 'FDC9'], 'Mohar': [26, 1.5, 'FDE3', 'FDC1', 'FDE1', 'HDE4', 'HDC2', 'HDE3', 'FDC5', 'FDC4', 'HDC1', 'FDC2'], 'Violet': [27, 1.5, 'FDC1', 'FDE3', 'HDC1', 'FDE6', 'FDC2', 'FDC8', 'HDE4', 'FDC10', 'HDE3', 'HDC4'], 'Daniel': [28, 1.5, 'FDC6', 'FDC5', 'FDC3', 'HDE2', 'FDC7', 'FDE2', 'HDE3', 'HDC4', 'FDE3', 'HDC1'], 'Penelope': [29, 1, 'FDC1', 'HDE4', 'HDE1', 'HDC2', 'FDE1', 'HDC4', 'FDC5', 'FDC10', 'FDE3', 'FDC6'], 'Uriel': [30, 1.5, 'FDC9', 'HDC3', 'FDE4', 'HDC4', 'FDC7', 'FDC3', 'FDC8', 'HDE4', 'HDE2', 'FDE5']}

# %%
FDC ={'FDC1': 1, 'FDC2': 1, 'FDC3': 1, 'FDC4': 1, 'FDC5': 1, 'FDC6': 1, 'FDC7': 1, 'FDC8': 1, 'FDC9': 1, 'FDC10': 1, 'FDC11': 1}
HDC={'HDC1': 1, 'HDC2': 1, 'HDC3': 1, 'HDC4': 1}
FDE = {'FDE1': 1, 'FDE2': 1, 'FDE3': 1, 'FDE4': 1, 'FDE5': 1, 'FDE6': 1}
HDE = {'HDE1': 1, 'HDE2': 1, 'HDE3': 1, 'HDE4': 1}
#courses_offered=['FDC','HDC','FDE','HDE']

# %%
allot_dict = {key: [] for key in set(FDC) | set(HDC) | set(FDE) | set(HDE)}

print(allot_dict)
# Out:
# {'FDC5': [], 'FDC3': [], 'FDE3': [], 'FDE6': [], 'FDC10': [], 'HDE1': [], 'FDC7': [], 'FDE2': [], 'HDE3': [], 'FDC1': [], 'FDC6': [], 'HDC3': [], 'HDC2': [], 'FDE5': [], 'FDE4': [], 'FDC2': [], 'FDC8': [], 'HDE2': [], 'HDC4': [], 'HDE4': [], 'FDC11': [], 'FDE1': [], 'FDC9': [], 'FDC4': [], 'HDC1': []}

# %%
def assign_course(prof_name,course_name):
    for i in allot_dict:
        if i==course_name:
            allot_dict[i].append(prof_name)

# %%
def check_total(x):
    total=0
    for i in x:
        total+=x[i]
    if total==0:
        return True
    else:
        return False

# %%
for key in proff_dict:
    for once in only_once:
        if once in proff_dict[key] and proff_dict[key][1] in [1,1.5]:
            assign_course(key,once)
            proff_dict[key][1]-=1
            if once.startswith("FDC"):
                FDC[once]-=1
            elif once.startswith("HDC"):
                HDC[once]-=1

# %%
def preference_priority(x):
    if x==FDC:
        y='FDC'
    elif x==HDC:
        y='HDC'
    elif x==FDE:
        y='FDE'
    elif x==HDE:
        y='HDE'
    
    for i in range(2,12):
        for name in proff_dict:
            if proff_dict[name][i].startswith(y):
                course_name=proff_dict[name][i]
                if course_name in x:
                    if x[course_name] in [0.5,1] and proff_dict[name][1] in [0.5,1.5]:
                        if proff_dict[name][1] in [0.5,1.5] and course_name not in only_once:
                            assign_course(name,course_name)
                            x[course_name]-=0.5
                            proff_dict[name][1]-=0.5
                        elif proff_dict[name][1]==1.5 and course_name in only_once:
                            assign_course(name,course_name)
                            x[course_name]-=1
                            proff_dict[name][1]-=1
                    elif x[course_name]==1 and proff_dict[name][1] in [1,1.5]:
                        assign_course(name,course_name)
                        x[course_name]=0
                        proff_dict[name][1]-=1
        if check_total(x):
            break

# %%
# for i in range(1):
#     preference_priority(FDC)
#     if check_total(FDC)==True:
#         preference_priority(HDC)
#         if check_total(HDC)==True:
#             preference_priority(FDE)
#             if check_total(FDE)==True:
#                 preference_priority(HDE)
#         else:
#             continue
#     else:
#         continue 
preference_priority(FDC)
preference_priority(HDC)
preference_priority(FDE)
preference_priority(HDE)

# %%
FDC
# Out:
# {'FDC1': 0.0,
#  'FDC2': 0,
#  'FDC3': 0.0,
#  'FDC4': 0,
#  'FDC5': 0,
#  'FDC6': 0.0,
#  'FDC7': 0.0,
#  'FDC8': 0,
#  'FDC9': 0,
#  'FDC10': 0.0,
#  'FDC11': 0}

# %%
HDC
# Out:
# {'HDC1': 0.0, 'HDC2': 0, 'HDC3': 0.0, 'HDC4': 0}

# %%
FDE
# Out:
# {'FDE1': 0, 'FDE2': 0.5, 'FDE3': 0.0, 'FDE4': 0, 'FDE5': 0.0, 'FDE6': 0.0}

# %%
HDE
# Out:
# {'HDE1': 0, 'HDE2': 0, 'HDE3': 0, 'HDE4': 0}

# %%
allot_dict
# Out:
# {'FDC5': ['Oliver'],
#  'FDC3': ['Delilah', 'Isaac'],
#  'FDE3': ['Donald', 'Bella'],
#  'FDE6': ['Abdul', 'William'],
#  'FDC10': ['Zari', 'Jasmine'],
#  'HDE1': ['Quentin'],
#  'FDC7': ['Tessa', 'Fiona'],
#  'FDE2': ['Xena'],
#  'HDE3': ['Yosef'],
#  'FDC1': ['Sebastian', 'Violet'],
#  'FDC6': ['Gabriel', 'Daniel'],
#  'HDC3': ['Uriel', 'Aiden'],
#  'HDC2': ['Mason'],
#  'FDE5': ['Hannah', 'Ethan'],
#  'FDE4': ['Uriel'],
#  'FDC2': ['Lily'],
#  'FDC8': ['Nora'],
#  'HDE2': ['William'],
#  'HDC4': ['Tessa'],
#  'HDE4': ['Penelope'],
#  'FDC11': ['Ethan'],
#  'FDE1': ['Donald'],
#  'FDC9': ['Rose'],
#  'FDC4': ['Kaden'],
#  'HDC1': ['Caleb', 'Yosef']}

# %%
for key in FDE:
    if FDE[key]==0.5:
        FDE[key]+=0.5
        proff=allot_dict[key][0]
        allot_dict[key]=[]
        proff_dict[proff][1]+=0.5
for key in HDE:
    if HDE[key]==0.5:
        HDE[key]+=0.5
        proff=allot_dict[key][0]
        allot_dict[key]=[]
        proff_dict[proff][1]+=0.5
allot_dict
# Out:
# {'FDC5': ['Oliver'],
#  'FDC3': ['Delilah', 'Isaac'],
#  'FDE3': ['Donald', 'Bella'],
#  'FDE6': ['Abdul', 'William'],
#  'FDC10': ['Zari', 'Jasmine'],
#  'HDE1': ['Quentin'],
#  'FDC7': ['Tessa', 'Fiona'],
#  'FDE2': [],
#  'HDE3': ['Yosef'],
#  'FDC1': ['Sebastian', 'Violet'],
#  'FDC6': ['Gabriel', 'Daniel'],
#  'HDC3': ['Uriel', 'Aiden'],
#  'HDC2': ['Mason'],
#  'FDE5': ['Hannah', 'Ethan'],
#  'FDE4': ['Uriel'],
#  'FDC2': ['Lily'],
#  'FDC8': ['Nora'],
#  'HDE2': ['William'],
#  'HDC4': ['Tessa'],
#  'HDE4': ['Penelope'],
#  'FDC11': ['Ethan'],
#  'FDE1': ['Donald'],
#  'FDC9': ['Rose'],
#  'FDC4': ['Kaden'],
#  'HDC1': ['Caleb', 'Yosef']}

# %%
print(HDE)
FDE
# Out:
# {'HDE1': 0, 'HDE2': 0, 'HDE3': 0, 'HDE4': 0}
# {'FDE1': 0, 'FDE2': 1.0, 'FDE3': 0.0, 'FDE4': 0, 'FDE5': 0.0, 'FDE6': 0.0}

# %%
r_proff=[]
for prof in proff_dict:
    if(proff_dict[prof][1]!=0):
        r_proff.append(prof)

# %%
df = pd.DataFrame(allot_dict.items(), columns=['Courses', 'Professors'])
df[['Professor1', 'Professor2']] = pd.DataFrame(df['Professors'].tolist(),index=df.index)
df = df.drop(columns='Professors')
def custom_sort(course):
    letters = course[:3]
    number = int(course[3:])
    category_order = {'FDC': 1, 'HDC': 2, 'FDE': 3, 'HDE': 4}
    return (category_order[letters], number)

df['sort_key'] = df['Courses'].apply(custom_sort)
df = df.sort_values('sort_key').drop(columns='sort_key')
df = df.reset_index(drop=True)

# %%
def red(x):
    if pd.isna(x):
        return 'font-weight: bold; color: red'
    else:
        return ''

styled_df = df.style.applymap(red)
styled_df.to_excel('styled_dataset.xlsx', index=False)
styled_df
# Out:
# <style type="text/css">
# #T_0afc9_row1_col2, #T_0afc9_row3_col2, #T_0afc9_row4_col2, #T_0afc9_row7_col2, #T_0afc9_row8_col2, #T_0afc9_row10_col2, #T_0afc9_row12_col2, #T_0afc9_row14_col2, #T_0afc9_row15_col2, #T_0afc9_row16_col1, #T_0afc9_row16_col2, #T_0afc9_row18_col2, #T_0afc9_row21_col2, #T_0afc9_row22_col2, #T_0afc9_row23_col2, #T_0afc9_row24_col2 {
#   font-weight: bold;
#   color: red;
# }
# </style>
# <table id="T_0afc9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0afc9_level0_col0" class="col_heading level0 col0" >Courses</th>
#       <th id="T_0afc9_level0_col1" class="col_heading level0 col1" >Professor1</th>
#       <th id="T_0afc9_level0_col2" class="col_heading level0 col2" >Professor2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0afc9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0afc9_row0_col0" class="data row0 col0" >FDC1</td>
#       <td id="T_0afc9_row0_col1" class="data row0 col1" >Sebastian</td>
#       <td id="T_0afc9_row0_col2" class="data row0 col2" >Violet</td>
#     </tr>
#     <tr>
#       <th id="T_0afc9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0afc9_row1_col0" class="data row1 col0" >FDC2</td>
#       <td id="T_0afc9_row1_col1" class="data row1 col1" >Lily</td>
#       <td id="T_0afc9_row1_col2" class="data row1 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0afc9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0afc9_row2_col0" class="data row2 col0" >FDC3</td>
#       <td id="T_0afc9_row2_col1" class="data row2 col1" >Delilah</td>
#       <td id="T_0afc9_row2_col2" class="data row2 col2" >Isaac</td>
#     </tr>
#     <tr>
#       <th id="T_0afc9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0afc9_row3_col0" class="data row3 col0" >FDC4</td>
#       <td id="T_0afc9_row3_col1" class="data row3 col1" >Kaden</td>
#       <td id="T_0afc9_row3_col2" class="data row3 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0afc9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0afc9_row4_col0" class="data row4 col0" >FDC5</td>
#       <td id="T_0afc9_row4_col1" class="data row4 col1" >Oliver</td>
#       <td id="T_0afc9_row4_col2" class="data row4 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0afc9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0afc9_row5_col0" class="data row5 col0" >FDC6</td>
#       <td id="T_0afc9_row5_col1" class="data row5 col1" >Gabriel</td>
#       <td id="T_0afc9_row5_col2" class="data row5 col2" >Daniel</td>
#     </tr>
#     <tr>
#       <th id="T_0afc9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0afc9_row6_col0" class="data row6 col0" >FDC7</td>
#       <td id="T_0afc9_row6_col1" class="data row6 col1" >Tessa</td>
#       <td id="T_0afc9_row6_col2" class="data row6 col2" >Fiona</td>
#     </tr>
#     <tr>
#       <th id="T_0afc9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0afc9_row7_col0" class="data row7 col0" >FDC8</td>
#       <td id="T_0afc9_row7_col1" class="data row7 col1" >Nora</td>
#       <td id="T_0afc9_row7_col2" class="data row7 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0afc9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0afc9_row8_col0" class="data row8 col0" >FDC9</td>
#       <td id="T_0afc9_row8_col1" class="data row8 col1" >Rose</td>
#       <td id="T_0afc9_row8_col2" class="data row8 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0afc9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0afc9_row9_col0" class="data row9 col0" >FDC10</td>
#       <td id="T_0afc9_row9_col1" class="data row9 col1" >Zari</td>
#       <td id="T_0afc9_row9_col2" class="data row9 col2" >Jasmine</td>
#     </tr>
#     <tr>
#       <th id="T_0afc9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0afc9_row10_col0" class="data row10 col0" >FDC11</td>
#       <td id="T_0afc9_row10_col1" class="data row10 col1" >Ethan</td>
#       <td id="T_0afc9_row10_col2" class="data row10 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0afc9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0afc9_row11_col0" class="data row11 col0" >HDC1</td>
#       <td id="T_0afc9_row11_col1" class="data row11 col1" >Caleb</td>
#       <td id="T_0afc9_row11_col2" class="data row11 col2" >Yosef</td>
#     </tr>
#     <tr>
#       <th id="T_0afc9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0afc9_row12_col0" class="data row12 col0" >HDC2</td>
#       <td id="T_0afc9_row12_col1" class="data row12 col1" >Mason</td>
#       <td id="T_0afc9_row12_col2" class="data row12 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0afc9_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0afc9_row13_col0" class="data row13 col0" >HDC3</td>
#       <td id="T_0afc9_row13_col1" class="data row13 col1" >Uriel</td>
#       <td id="T_0afc9_row13_col2" class="data row13 col2" >Aiden</td>
#     </tr>
#     <tr>
#       <th id="T_0afc9_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0afc9_row14_col0" class="data row14 col0" >HDC4</td>
#       <td id="T_0afc9_row14_col1" class="data row14 col1" >Tessa</td>
#       <td id="T_0afc9_row14_col2" class="data row14 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0afc9_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0afc9_row15_col0" class="data row15 col0" >FDE1</td>
#       <td id="T_0afc9_row15_col1" class="data row15 col1" >Donald</td>
#       <td id="T_0afc9_row15_col2" class="data row15 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0afc9_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_0afc9_row16_col0" class="data row16 col0" >FDE2</td>
#       <td id="T_0afc9_row16_col1" class="data row16 col1" >None</td>
#       <td id="T_0afc9_row16_col2" class="data row16 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0afc9_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_0afc9_row17_col0" class="data row17 col0" >FDE3</td>
#       <td id="T_0afc9_row17_col1" class="data row17 col1" >Donald</td>
#       <td id="T_0afc9_row17_col2" class="data row17 col2" >Bella</td>
#     </tr>
#     <tr>
#       <th id="T_0afc9_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_0afc9_row18_col0" class="data row18 col0" >FDE4</td>
#       <td id="T_0afc9_row18_col1" class="data row18 col1" >Uriel</td>
#       <td id="T_0afc9_row18_col2" class="data row18 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0afc9_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_0afc9_row19_col0" class="data row19 col0" >FDE5</td>
#       <td id="T_0afc9_row19_col1" class="data row19 col1" >Hannah</td>
#       <td id="T_0afc9_row19_col2" class="data row19 col2" >Ethan</td>
#     </tr>
#     <tr>
#       <th id="T_0afc9_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_0afc9_row20_col0" class="data row20 col0" >FDE6</td>
#       <td id="T_0afc9_row20_col1" class="data row20 col1" >Abdul</td>
#       <td id="T_0afc9_row20_col2" class="data row20 col2" >William</td>
#     </tr>
#     <tr>
#       <th id="T_0afc9_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_0afc9_row21_col0" class="data row21 col0" >HDE1</td>
#       <td id="T_0afc9_row21_col1" class="data row21 col1" >Quentin</td>
#       <td id="T_0afc9_row21_col2" class="data row21 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0afc9_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_0afc9_row22_col0" class="data row22 col0" >HDE2</td>
#       <td id="T_0afc9_row22_col1" class="data row22 col1" >William</td>
#       <td id="T_0afc9_row22_col2" class="data row22 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0afc9_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_0afc9_row23_col0" class="data row23 col0" >HDE3</td>
#       <td id="T_0afc9_row23_col1" class="data row23 col1" >Yosef</td>
#       <td id="T_0afc9_row23_col2" class="data row23 co

# %%
professor_counts = df[['Professor1', 'Professor2']].count(axis=1)

plt.figure(figsize=(10, 6))
plt.bar(df['Courses'], professor_counts, color='skyblue')
plt.xlabel('Courses')
plt.ylabel('Number of Professors')
plt.title('Number of Professors per Course')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# import pandas as pd
# import networkx as nx
# import matplotlib.pyplot as plt

# # Your dataframe


# # Create a list of edges (course, professor)
# edges = []
# for _, row in df.iterrows():
#     course = row['Courses']
#     professor1 = row['Professor1']
#     professor2 = row['Professor2']

#     if professor1 is not None:
#         edges.append((course, professor1))
    
#     if professor2 is not None:
#         edges.append((course, professor2))

# # Create a directed graph
# G = nx.DiGraph()

# # Add edges to the graph
# G.add_edges_from(edges)

# # Increase the size of the graph
# fig, ax = plt.subplots(figsize=(16, 8))  # Adjust the width and height as needed

# # Plot the graph
# pos = nx.spring_layout(G)  # You can choose a different layout if needed
# node_size = 1000
# nx.draw(G, pos, with_labels=True, font_size=7, node_size=node_size, node_color='lightblue', font_color='black', font_weight='bold', arrowsize=10, ax=ax)

# # Add a title to the plot
# ax.set_title("Course-Professor Relationship")

# # Display the plot
# plt.show()

# %%
import pandas as pd
from itertools import zip_longest
import networkx as nx
import matplotlib.pyplot as plt

# Your modified data


# Use zip_longest to ensure equal length, filling with None
zipped_data = zip_longest(df['Courses'], df['Professor1'], df['Professor2'])

# Create DataFrame from zipped data
df = pd.DataFrame(zipped_data, columns=['Courses', 'Professor1', 'Professor2'])

# Drop rows where 'Courses' is None
df = df.dropna(subset=['Courses'])

# Continue with the rest of the code for creating and plotting the bipartite graph

# Create a list of edges (course, professor)
edges = []
for _, row in df.iterrows():
    course = row['Courses']
    professor1 = row['Professor1']
    professor2 = row['Professor2']

    if professor1 is not None:
        edges.append((course, professor1))

    if professor2 is not None:
        edges.append((course, professor2))

# Create a bipartite graph
B = nx.Graph()

# Add nodes with the 'bipartite' attribute
B.add_nodes_from(df['Courses'], bipartite=0)  # Courses
B.add_nodes_from(df['Professor1'].dropna(), bipartite=1)  # Professors
B.add_nodes_from(df['Professor2'].dropna(), bipartite=1)  # Professors

# Add edges to the bipartite graph
B.add_edges_from(edges)

# Separate nodes into two sets for bipartite layout
courses = {node for node, bipartite in nx.get_node_attributes(B, 'bipartite').items() if bipartite == 0}
professors = {node for node, bipartite in nx.get_node_attributes(B, 'bipartite').items() if bipartite == 1}

# Compute bipartite layout
pos = dict()
pos.update((node, (1, index)) for index, node in enumerate(courses))
pos.update((node, (2, index)) for index, node in enumerate(professors))

# Create a new figure
fig, ax = plt.subplots(figsize=(50, 80)) 
# Plot the bipartite graph
node_size = 21000
nx.draw(B, pos, with_labels=True, font_size=40, node_size=node_size, node_color='lightblue', font_color='black',font_weight='bold',arrowsize=50, ax=ax)

# Add a title to the plot
ax.set_title("Bipartite Course-Professor Relationship",fontsize=70,y=0.95)
print()
print()
# Display the plot
plt.show()

# %%
for _, row in df.iterrows():
    course = row['Courses']
    professor1 = row['Professor1']
    professor2 = row['Professor2']
    print(course,professor1,professor2)
# Out:
# FDC1 Sebastian Violet
# FDC2 Lily None
# FDC3 Delilah Isaac
# FDC4 Kaden None
# FDC5 Oliver None
# FDC6 Gabriel Daniel
# FDC7 Tessa Fiona
# FDC8 Nora None
# FDC9 Rose None
# FDC10 Zari Jasmine
# FDC11 Ethan None
# HDC1 Caleb Yosef
# HDC2 Mason None
# HDC3 Uriel Aiden
# HDC4 Tessa None
# FDE1 Donald None
# FDE2 None None
# FDE3 Donald Bella
# FDE4 Uriel None
# FDE5 Hannah Ethan
# FDE6 Abdul William
# HDE1 Quentin None
# HDE2 William None
# HDE3 Yosef None
# HDE4 Penelope None

# %%
df.iterrows
# Out:
# <bound method DataFrame.iterrows of    Courses Professor1 Professor2
# 0     FDC1  Sebastian     Violet
# 1     FDC2       Lily       None
# 2     FDC3    Delilah      Isaac
# 3     FDC4      Kaden       None
# 4     FDC5     Oliver       None
# 5     FDC6    Gabriel     Daniel
# 6     FDC7      Tessa      Fiona
# 7     FDC8       Nora       None
# 8     FDC9       Rose       None
# 9    FDC10       Zari    Jasmine
# 10   FDC11      Ethan       None
# 11    HDC1      Caleb      Yosef
# 12    HDC2      Mason       None
# 13    HDC3      Uriel      Aiden
# 14    HDC4      Tessa       None
# 15    FDE1     Donald       None
# 16    FDE2       None       None
# 17    FDE3     Donald      Bella
# 18    FDE4      Uriel       None
# 19    FDE5     Hannah      Ethan
# 20    FDE6      Abdul    William
# 21    HDE1    Quentin       None
# 22    HDE2    William       None
# 23    HDE3      Yosef       None
# 24    HDE4   Penelope       None>
